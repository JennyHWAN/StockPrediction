# %%
from prophet import Prophet
import yfinance
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 from fbprophet import Prophet
#       2 import yfinance
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
# !pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.1.3.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 175.7 kB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting LunarCalendar>=0.0.9
#   Using cached LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: tqdm>=4.36.1 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from prophet) (4.64.0)
# Collecting cmdstanpy>=1.0.4
#   Using cached cmdstanpy-1.1.0-py3-none-any.whl (83 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from prophet) (3.7.1)
# Requirement already satisfied: numpy>=1.15.4 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from prophet) (1.22.4)
# Requirement already satisfied: importlib-resources in /Users/jennyhuang/yes/lib/python3.9/site-packages (from prophet) (5.8.0)
# Requirement already satisfied: pandas>=1.0.4 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from prophet) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from prophet) (2.8.2)
# Collecting holidays>=0.14.2
#   Using cached holidays-0.25-py3-none-any.whl (514 kB)
# Collecting convertdate>=2.1.2
#   Using cached convertdate-2.4.0-py3-none-any.whl (47 kB)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: korean-lunar-calendar in /Users/jennyhuang/yes/lib/python3.9/site-packages (from holidays>=0.14.2->prophet) (0.3.1)
# Requirement already satisfied: pytz in /Users/jennyhuang/yes/lib/python3.9/site-packages (from LunarCalendar>=0.0.9->prophet) (2023.3)
# Collecting ephem>=3.7.5.3
#   Using cached ephem-4.1.4.tar.gz (1.3 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=20.0 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from importlib-resources->prophet) (3.8.0)
# Requirement already satisfied: six>=1.5 in /Users/jennyhuang/yes/lib/python3.9/site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Building wheels for collected packages: prophet, ephem
#   Building wheel for prophet (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for prophet (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [159 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.0-arm64-cpython-39
#       creating build/lib.macosx-11.0-arm64-cpython-39/prophet
#       creating build/lib.macosx-11.0-arm64-cpython-39/prophet/stan_model
#       Compiling cmdstanpy model
#       Installing cmdstan to /private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-install-n41fsmcb/prophet_3c6cfa0f35cf489fa4490c1fe530ea47/build/lib.macosx-11.0-arm64-cpython-39/prophet/stan_model/cmdstan-2.26.1
#       Installing CmdStan version: 2.26.1
#       Install directory: /private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-install-n41fsmcb/prophet_3c6cfa0f35cf489fa4490c1fe530ea47/build/lib.macosx-11.0-arm64-cpython-39/prophet/stan_model
#       Downloading CmdStan version 2.26.1
#
#       0.00B [00:00, ?B/s]
#         0%|          | 0.00/46.3M [00:00<?, ?B/s]
#         0%|          | 40.0k/46.3M [00:00<04:38, 174kB/s]
#         0%|          | 104k/46.3M [00:00<02:20, 345kB/s]
#         0%|          | 152k/46.3M [00:00<02:23, 336kB/s]
#         1%|          | 264k/46.3M [00:00<01:40, 478kB/s]
#         1%|          | 440k/46.3M [00:00<00:58, 817kB/s]
#         1%|          | 584k/46.3M [00:00<00:51, 939kB/s]
#         2%|▏         | 904k/46.3M [00:00<00:30, 1.56MB/s]
#         3%|▎         | 1.16M/46.3M [00:01<00:25, 1.84MB/s]
#         4%|▎         | 1.73M/46.3M [00:01<00:15, 2.93MB/s]
#         5%|▌         | 2.35M/46.3M [00:01<00:12, 3.72MB/s]
#         7%|▋         | 3.20M/46.3M [00:01<00:08, 5.09MB/s]
#        10%|█         | 4.74M/46.3M [00:01<00:05, 7.72MB/s]
#        13%|█▎        | 5.98M/46.3M [00:01<00:04, 9.14MB/s]
#        16%|█▌        | 7.26M/46.3M [00:01<00:03, 10.3MB/s]
#        20%|█▉        | 9.05M/46.3M [00:01<00:03, 12.7MB/s]
#        22%|██▏       | 10.3M/46.3M [00:01<00:03, 12.5MB/s]
#        26%|██▌       | 12.0M/46.3M [00:02<00:02, 14.0MB/s]
#        29%|██▉       | 13.3M/46.3M [00:02<00:02, 12.6MB/s]
#        32%|███▏      | 14.9M/46.3M [00:02<00:02, 12.1MB/s]
#        36%|███▌      | 16.5M/46.3M [00:02<00:02, 13.4MB/s]
#        39%|███▉      | 18.1M/46.3M [00:02<00:02, 14.1MB/s]
#        43%|████▎     | 19.9M/46.3M [00:02<00:01, 15.2MB/s]
#        46%|████▋     | 21.4M/46.3M [00:02<00:01, 15.6MB/s]
#        50%|████▉     | 23.0M/46.3M [00:05<00:14, 1.74MB/s]
#        52%|█████▏    | 24.0M/46.3M [00:06<00:14, 1.61MB/s]
#        54%|█████▎    | 24.8M/46.3M [00:06<00:13, 1.64MB/s]
#        55%|█████▍    | 25.4M/46.3M [00:07<00:12, 1.68MB/s]
#        56%|█████▌    | 25.9M/46.3M [00:07<00:13, 1.62MB/s]
#        60%|█████▉    | 27.6M/46.3M [00:07<00:07, 2.70MB/s]
#        63%|██████▎   | 29.2M/46.3M [00:07<00:04, 4.06MB/s]
#        65%|██████▌   | 30.3M/46.3M [00:08<00:04, 3.54MB/s]
#        73%|███████▎  | 33.9M/46.3M [00:08<00:02, 6.36MB/s]
#        77%|███████▋  | 35.6M/46.3M [00:08<00:01, 7.66MB/s]
#        80%|████████  | 37.1M/46.3M [00:08<00:01, 8.78MB/s]
#        83%|████████▎ | 38.3M/46.3M [00:08<00:00, 8.56MB/s]
#        87%|████████▋ | 40.2M/46.3M [00:09<00:00, 10.5MB/s]
#        90%|█████████ | 41.8M/46.3M [00:09<00:00, 11.6MB/s]
#        93%|█████████▎| 43.1M/46.3M [00:09<00:00, 10.5MB/s]
#        97%|█████████▋| 44.8M/46.3M [00:09<00:00, 11.9MB/s]
#
#       Download successful, file: /var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/tmpbmhploxv
#       Extracting distribution
#
#         0%|          | 0/32103 [00:00<?, ?it/s]
#         1%|          | 270/32103 [00:00<00:17, 1860.45it/s]
#         1%|▏         | 457/32103 [00:00<00:18, 1731.58it/s]
#         4%|▎         | 1197/32103 [00:00<00:07, 3978.93it/s]
#         6%|▌         | 1965/32103 [00:00<00:05, 5316.35it/s]
#         9%|▉         | 2949/32103 [00:00<00:04, 6855.94it/s]
#        12%|█▏        | 3746/32103 [00:00<00:03, 7218.23it/s]
#        14%|█▍        | 4596/32103 [00:00<00:03, 7625.02it/s]
#        17%|█▋        | 5374/32103 [00:00<00:03, 7666.77it/s]
#        19%|█▉        | 6152/32103 [00:00<00:03, 7426.67it/s]
#        22%|██▏       | 6917/32103 [00:01<00:03, 7491.60it/s]
#        24%|██▍       | 7817/32103 [00:01<00:03, 7941.31it/s]
#        27%|██▋       | 8668/32103 [00:01<00:02, 8110.51it/s]
#        30%|██▉       | 9484/32103 [00:01<00:02, 7711.82it/s]
#        32%|███▏      | 10351/32103 [00:01<00:02, 7986.97it/s]
#        35%|███▍      | 11204/32103 [00:01<00:02, 8144.66it/s]
#        38%|███▊      | 12104/32103 [00:01<00:02, 8395.42it/s]
#        40%|████      | 12948/32103 [00:01<00:02, 8366.69it/s]
#        43%|████▎     | 13899/32103 [00:01<00:02, 8704.32it/s]
#        46%|████▌     | 14829/32103 [00:01<00:01, 8881.31it/s]
#        49%|████▉     | 15744/32103 [00:02<00:01, 8958.54it/s]
#        52%|█████▏    | 16642/32103 [00:02<00:01, 8682.71it/s]
#        55%|█████▍    | 17513/32103 [00:02<00:01, 8219.50it/s]
#        57%|█████▋    | 18342/32103 [00:02<00:01, 7891.44it/s]
#        60%|██████    | 19282/32103 [00:02<00:01, 8311.11it/s]
#        63%|██████▎   | 20185/32103 [00:02<00:01, 8515.40it/s]
#        66%|██████▌   | 21100/32103 [00:02<00:01, 8696.91it/s]
#        68%|██████▊   | 21975/32103 [00:02<00:01, 8638.17it/s]
#        71%|███████▏  | 22881/32103 [00:02<00:01, 8760.75it/s]
#        74%|███████▍  | 23773/32103 [00:03<00:00, 8805.39it/s]
#        77%|███████▋  | 24725/32103 [00:03<00:00, 9016.70it/s]
#        80%|███████▉  | 25629/32103 [00:03<00:00, 8854.20it/s]
#        83%|████████▎ | 26517/32103 [00:03<00:00, 8155.89it/s]
#        85%|████████▌ | 27344/32103 [00:03<00:00, 8038.80it/s]
#        88%|████████▊ | 28156/32103 [00:03<00:00, 7871.57it/s]
#        90%|█████████ | 28971/32103 [00:03<00:00, 7949.30it/s]
#        93%|█████████▎| 29878/32103 [00:03<00:00, 8270.60it/s]
#        96%|█████████▌| 30811/32103 [00:03<00:00, 8576.84it/s]
#        99%|█████████▉| 31765/32103 [00:03<00:00, 8857.42it/s]
#
#       Unpacked download as cmdstan-2.26.1
#       Building version cmdstan-2.26.1, may take several minutes, depending on your system.
#       cmd: make build -j8
#       cwd: None
#       12:26:21 - cmdstanpy - WARNING - CmdStan installation failed.
#       Command "make build" failed
#       Command ['make', 'build', '-j8']
#           error during processing Disc quota exceeded
#       CmdStan installation failed.
#       Command "make build" failed
#       Command ['make', 'build', '-j8']
#           error during processing Disc quota exceeded
#
#       You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#       Traceback (most recent call last):
#         File "/Users/jennyhuang/yes/lib/python3.9/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/jennyhuang/yes/lib/python3.9/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/Users/jennyhuang/yes/lib/python3.9/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 251, in build_wheel
#           return _build_backend().build_wheel(wheel_directory, config_settings,
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 416, in build_wheel
#           return self._build_with_temp_dir(['bdist_wheel'], '.whl',
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 401, in _build_with_temp_dir
#           self.run_setup()
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/build_meta.py", line 338, in run_setup
#           exec(code, locals())
#         File "<string>", line 183, in <module>
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/__init__.py", line 107, in setup
#           return distutils.core.setup(**attrs)
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/wheel/bdist_wheel.py", line 343, in run
#           self.run_command("build")
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/_distutils/command/build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/dist.py", line 1244, in run_command
#           super().run_command(command)
#         File "/private/var/folders/20/h9hzw4qs64321s82n6w8zjyr0000gn/T/pip-build-env-h6lnhfkt/overlay/lib/python3.9/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "<string>", line 144, in run
#         File "<string>", line 131, in build_models
#         File "<string>", line 110, in build_cmdstan_model
#         File "<string>", line 94, in install_cmdstan_deps
#       RuntimeError: CmdStan failed to install in repackaged directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for prophet
#   Building wheel for ephem (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [78 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.0-arm64-cpython-39
#       creating build/lib.macosx-11.0-arm64-cpython-39/ephem
#       copying ephem/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem
#       copying ephem/stars.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem
#       copying ephem/cities.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem
#       creating build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_usno_equinoxes.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_stars.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_cities.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_dates.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_launchpad_244811.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/__init__.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_observers.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_rise_set.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_launchpad_236872.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_jpl.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_locales.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_rst.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_github_issues.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_usno.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_bodies.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_constants.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_satellite.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       copying ephem/tests/test_angles.py -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests
#       creating build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/angle.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/index.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/tutorial.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/examples.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/coordinates.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/toc.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/quick.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/rise-set.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/date.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/CHANGELOG.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/radec.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/newton.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       copying ephem/doc/catalogs.rst -> build/lib.macosx-11.0-arm64-cpython-39/ephem/doc
#       creating build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/jpl
#       copying ephem/tests/jpl/phobos.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/jpl
#       copying ephem/tests/jpl/europa.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/jpl
#       copying ephem/tests/jpl/uranus.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/jpl
#       copying ephem/tests/jpl/jupiter.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/jpl
#       copying ephem/tests/jpl/hyperion.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/jpl
#       copying ephem/tests/jpl/oberon.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/jpl
#       copying ephem/tests/jpl/mars.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/jpl
#       copying ephem/tests/jpl/saturn.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/jpl
#       copying ephem/tests/jpl/neptune.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/jpl
#       creating build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/apptopo_deneb.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/astrom_mercury.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/appgeo_deneb.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/apptopo_moon.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/risettran_rigel.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/risettran_moon.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/astrom_neptune.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/riset_sun.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/apptopo_sun.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/appgeo_moon.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/appgeo_jupiter.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/astrom_antares.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/moon_phases.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/riset_moon.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       copying ephem/tests/usno/appgeo_sun.txt -> build/lib.macosx-11.0-arm64-cpython-39/ephem/tests/usno
#       running build_ext
#       building 'ephem._libastro' extension
#       creating build/temp.macosx-11.0-arm64-cpython-39
#       creating build/temp.macosx-11.0-arm64-cpython-39/extensions
#       creating build/temp.macosx-11.0-arm64-cpython-39/extensions/data
#       creating build/temp.macosx-11.0-arm64-cpython-39/libastro
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/jennyhuang/yes/include -arch arm64 -fPIC -O2 -isystem /Users/jennyhuang/yes/include -arch arm64 -Ilibastro -I. -I/Users/jennyhuang/yes/include/python3.9 -c extensions/_libastro.c -o build/temp.macosx-11.0-arm64-cpython-39/extensions/_libastro.o -ffloat-store
#
#       You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#       error: command '/usr/bin/clang' failed with exit code 69
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for ephem
#   Running setup.py clean for ephem
# Failed to build prophet ephem
# ERROR: Could not build wheels for prophet, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
train_size = 252*3                     # Use 3 years of data as train set
val_size = 252                         # Use 1 year of data as validation set
train_val_size = train_size + val_size # Size of train+validation set
i = train_val_size                     # Day to forecast
H = 21                                 # Forecast horizon

# Fit prophet model
m = Prophet()
m.fit(df_prophet[i-train_val_size:i])

# Create dataframe with the dates we want to predict
future = m.make_future_dataframe(periods=2*H)

# Eliminate weekend from future dataframe
future['day'] = future['ds'].dt.weekday
future = future[future['day']<=4]

# Predict
forecast = m.predict(future)
